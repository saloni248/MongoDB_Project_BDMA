# %% [markdown]
# # Movies Database Dashboard
#
# ## **Project Report** : Movies Sales Dashboard with MongoDB CRUD Operations and Analytics
# ### Submitted to:
# **Prof. Amarnath Mitra**
#
# ### Submitted by:
# **055026 - Navneet Mittal**
# **055039 - Saloni Gupta**

# %% [markdown]
# # 🎬 Movies Sales Dashboard with MongoDB CRUD Operations
#
# ## **Project Overview**
# This project aims to build a **Movies Sales Dashboard** using **MongoDB Atlas**, where CRUD operations (**Create, Read, Update, Delete**) will be performed on a movie dataset. The dashboard will include **advanced querying, filtering, aggregation, and logical operations** to analyze movie sales, ratings, and performance trends efficiently. The end goal is to develop an **interactive dashboard** that provides valuable **insights into movie performance**, helping businesses make data-driven decisions.
#
# ---
#
# ## **Key Features & Functionalities**
#
# ✅ **Data Management with MongoDB Atlas**
# - Perform **Insert, Update, Delete, and Find** operations on the movie dataset.
# - Implement **data filtering, comparisons, and logical operations** (`$and`, `$or`, `$not`).
# - Utilize **aggregation pipelines** to derive meaningful insights.
#
# ✅ **Advanced Querying & Data Exploration**
# - Find movies based on **ratings, genres, directors, box office collections, and awards**.
# - Filter movies using **comparative operators** (`$gt`, `$lt`, `$gte`, `$lte`).
# - Use **grouping and aggregation** for trend analysis.
#
# ✅ **Interactive Movie Sales Dashboard**
# - **Visual representation** of sales data, IMDb ratings, and box office trends.
# - **Filters and search functionality** for better user interaction.
# - Implement **charts and graphs** using visualization tools like Power BI, Tableau, or Python libraries.
#
# ✅ **Use Cases & Business Impact**
# - Track **box office revenue trends** for different movie genres.
# - Identify **top-performing directors, actors, and production houses**.
# - Analyze the impact of **awards and ratings on movie success**.
# - Predict **future movie trends** based on historical data.
#
# ---
#
# ## **Key Objectives**
#
# 🎯 **Efficient Movie Data Management**
# - Use MongoDB Atlas for structured and unstructured movie data storage.
# - Ensure **seamless CRUD operations** to manipulate the dataset effectively.
#
# 🎯 **Implement Advanced Querying**
# - Utilize **comparison operators** (`$gte`, `$lte`, `$eq`, etc.) to filter data dynamically.
# - Leverage **logical operators** (`$and`, `$or`, `$not`) for complex searches.
#
# 🎯 **Data Aggregation & Insights**
# - Perform **grouping and aggregation** to analyze trends across different attributes.
# - Use **MongoDB’s aggregation framework** to extract key insights.
#
# 🎯 **Dashboard Development & Visualization**
# - Create an **interactive dashboard** using tools like Streamlit, Power BI, or Tableau.
# - Use **charts, tables, and graphs** to visualize sales trends and insights.
#
# 🎯 **Real-World Business Impact**
# - Enable **data-driven decision-making** in the entertainment industry.
# - Provide insights on **movie sales trends, audience preferences, and market performance**.
#
# ---

# %% [markdown]
# # 🎬 **Movies Sales Dashboard - CRUD Operations in MongoDB Atlas**
#
# ## **📌 Project Overview**
# This project aims to develop a **Movies Sales Dashboard** using **MongoDB Atlas**, allowing efficient **CRUD operations** (Create, Read, Update, Delete) on a movie dataset. The dashboard will enable advanced **filtering, aggregation, and logical operations** to analyze **movie sales, ratings, and performance trends** effectively.
#
# ---
#
# # **1️⃣ CREATE (Insert Data)**
# ## **Problem Statement:**
# *"Insert new movies into the database, ensuring diverse genres, directors, and release years to expand the dataset for better analysis."*
#
# ## **MongoDB Queries and Problem Statements:**
#
# 📌 **Query 1: Insert a single movie into the database.**
# **Problem Statement:** *Add a newly released movie to the collection to keep the database updated with fresh content.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📌 **Query 2: Insert multiple movies at once.**
# **Problem Statement:** *Bulk insert movies to efficiently add diverse data points for better analysis.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2️⃣ READ (Query Data)**
# ## **Problem Statement:**
# *"Retrieve specific movie records based on filters like release year, rating, and genre to extract relevant insights from the dataset."*
#
# ## **MongoDB Queries and Problem Statements:**
#
# 📌 **Query 1: Find all movies in the database.**
# **Problem Statement:** *Fetch all stored movie records for a complete dataset overview.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **📌 Query 2: Find movies released in 2019.**
#
# **Problem Statement:** *Analyze movie trends for a specific year to understand industry performance.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📌 **Query 3: Find a movie by title (case-sensitive).**
#
# **Problem Statement:** *Search for a specific movie title to verify its existence in the database.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3️⃣ UPDATE (Modify Data)**
# ## **Problem Statement:**
# *"Modify existing movie records to correct data inaccuracies, add missing details, or enhance dataset quality for improved analysis."*
#
# ## **MongoDB Queries and Problem Statements:**
#
# 📌 **Query 1: Update the rating of "Joker".**
# **Problem Statement:** *Adjust movie ratings based on new critic reviews or audience feedback.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📌 **Query 2: Add a new genre to "Mad Max: Fury Road".**
# **Problem Statement:** *Enhance movie metadata by adding an additional relevant genre.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4️⃣ DELETE (Remove Data)**
# ## **Problem Statement:**
# *"Remove outdated or low-rated movies from the dataset to maintain data integrity and focus on high-quality records."*
#
# ## **MongoDB Queries and Problem Statements:**
#
# 📌 **Query 1: Delete a specific movie.**
# **Problem Statement:** *Remove a particular movie from the database due to incorrect data or poor audience reception.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📌 **Query 2: Delete all movies with a rating below 7.**
# **Problem Statement:** *Clear out low-rated movies to maintain a high-quality selection in the database.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📌 **Query 3: Delete all movies released before the year 2000.**
# **Problem Statement:** *Remove outdated movies that may no longer be relevant for modern audiences.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🎬 Movies Sample Dashboard - Insights & Analysis
#
# ## 📊 Number of Movies
#
# ### Problem Statement:
# Analyze the distribution of movies in the dataset to identify trends in production volume over time.
#
# ### Insights:
# - This graph showcases the total number of movies available in the dataset.
# - Helps in understanding movie production trends, including growth patterns and industry shifts.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🎭 Average Metacritic Score
#
# ### Problem Statement:
# Evaluate the overall quality of movies based on Metacritic scores to identify the standard of critical reception.
#
# ### Insights:
# - Presents the average Metacritic score for all movies, offering a snapshot of general movie quality based on critical reviews.
# - Useful for comparing critical reception across different movie categories.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🌍 Average Metacritic Score by Country
#
# ### Problem Statement:
# Compare the critical reception of movies across different countries to identify regions producing high-quality content.
#
# ### Insights:
# - This interactive map visualizes how movies from different countries are rated.
# - Helps in identifying patterns in critical acclaim based on geography.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🗣️ Top 10 Languages by Number of Movies
#
# ### Problem Statement:
# Identify the most dominant languages in the movie industry to understand linguistic diversity in cinema.
#
# ### Insights:
# - Lists the top 10 languages in which movies are produced.
# - Helps in understanding linguistic trends in global cinema.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 📅 Movies, Average Critic vs Viewer Review Scores by Decade
#
# ### Problem Statement:
# Analyze the evolution of movie ratings over time to understand audience and critic perception changes.
#
# ### Insights:
# - Compares critic and audience reviews across decades.
# - Showcases shifts in movie quality and audience preferences.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🏆 Most Awarded Directors with Average Metacritic Score
#
# ### Problem Statement:
# Identify the most influential directors based on awards and critical acclaim to highlight industry leaders.
#
# ### Insights:
# - Ranks directors by the number of awards and nominations they have received.
# - Shows the relationship between critical acclaim and recognition in the industry.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🔥 Movie Runtime vs Metacritic Score Heatmap
#
# ### Problem Statement:
# Investigate the relationship between movie length and critical reception to determine if runtime influences ratings.
#
# ### Insights:
# - Visualizes how movie runtime correlates with Metacritic scores.
# - Identifies patterns in movie length preferences.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🎭 Most Prolific Actors
#
# ### Problem Statement:
# Highlight the most frequently appearing actors in movies to understand the dominance of certain actors in the industry.
#
# ### Insights:
# - Lists actors with the highest number of movie appearances.
# - Helps in identifying industry favorites.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ⭐ Movie Ratings Distribution
#
# ### Problem Statement:
# Analyze the distribution of movie ratings to understand audience preferences and the proportion of highly-rated films.
#
# ### Insights:
# - Breaks down movie ratings, showcasing the spread of scores across different ranges.
# - Helps in identifying the proportion of highly-rated vs. low-rated movies.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🎬 Top 10 Genres by Number of Movies
#
# ### Problem Statement:
# Identify the most popular genres in cinema to understand audience and production trends.
#
# ### Insights:
# - Highlights the top genres by the number of movies produced.
# - Offers insights into industry focus areas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📌 **Observations & Findings**
#
# ### **1️⃣ CREATE (Insert Data) Observations:**
# - Successfully inserted **new movie records** into the database, ensuring diversity in **genres, directors, and release years**.
# - Bulk insertion of multiple records helped in **efficient database population**, reducing the time required for individual inserts.
# - By including movies with different ratings, the dataset allows for **analysis of high-rated vs. low-rated films**.
#
# ### **2️⃣ READ (Query Data) Observations:**
# - Retrieval of movies based on **specific filters** (e.g., year, genre, rating) was effective, allowing precise data extraction.
# - Queries using **logical operators** (`$or`, `$and`, `$not`) enhanced data filtering, making it possible to retrieve **highly-rated movies, genre-based selections, and director-specific collections**.
# - Use of **regular expressions (`$regex`)** helped in finding movies with **similar keywords in titles**, improving search capabilities.
# - Querying IMDb ratings and box office collections enabled **data-driven insights** into top-performing films.
#
# ### **3️⃣ UPDATE (Modify Data) Observations:**
# - Successfully updated movie records to **correct inaccuracies**, such as changing ratings based on critic reviews.
# - Added missing details (e.g., additional genres, financial data), ensuring **data completeness and integrity**.
# - Using `$inc` to **increase movie ratings for older films** provided a way to adjust scores based on new audience perceptions.
# - The `$push` and `$pull` operations efficiently **modified array fields**, allowing flexible updates for genres.
#
# ### **4️⃣ DELETE (Remove Data) Observations:**
# - Deleting low-rated movies (`rating < 7`) helped maintain a **high-quality selection** in the database.
# - Removing movies released before **the year 2000** eliminated **outdated records**, focusing on modern and relevant films.
# - The `deleteOne()` and `deleteMany()` operations provided **granular control** over removing **specific movies or bulk outdated records**.
#
# ### **5️⃣ DASHBOARD Observations:**
# - **Interactive Visualizations:** The dashboard effectively **visualizes key metrics** like movie ratings, Metacritic scores, and award-winning directors, making data analysis more intuitive.
# - **Filtering & Drill-downs:** Users can **filter movies by genre, country, and time periods**, enabling deeper insights into **industry trends**.
# - **Data-Driven Decision Making:** The dashboard allows quick identification of **top-performing movies, trends in movie ratings, and most influential directors**, aiding in strategic planning.
# - **Performance Optimization:** By focusing on **aggregated insights**, the dashboard presents **optimized data views**, ensuring smooth and quick analysis of large datasets.
#
# ### **💡 Key Takeaways:**
# ✔ **Data Filtering & Analysis:** The use of MongoDB queries enabled **targeted retrieval of relevant movie records**, supporting business intelligence.
# ✔ **Data Consistency:** Updates ensured **accurate, complete, and structured data**, improving dataset quality.
# ✔ **Optimized Database Storage:** By removing irrelevant movies, the database remains **optimized, efficient, and easy to manage**.
# ✔ **Scalability:** The structured use of **CRUD operations** allows seamless **database expansion and modifications**, ensuring long-term usability.
# ✔ **Actionable Insights:** The dashboard enhances **business decision-making** by providing **a structured view of movie industry trends**.

# %% [markdown]
# # 📌 **Managerial Insights & Recommendations**
#
# ### **1️⃣ Data-Driven Decision Making for Movie Success**
# - The analysis of **movie ratings, box office collections, and audience preferences** enables **data-driven decisions** for selecting high-potential films for streaming, re-releases, or promotions.
# - The ability to filter movies by **genres, directors, and financial success** provides valuable insights for **strategic content curation** in streaming platforms or theaters.
#
# ### **2️⃣ Optimizing Movie Catalog for Better Audience Engagement**
# - Removing **low-rated movies (`rating < 7`)** ensures that the platform maintains **high-quality content**, leading to **better user engagement and satisfaction**.
# - Updating **older movies’ ratings** based on modern audience feedback helps retain their **relevance and visibility**.
# - Categorizing movies efficiently using **genres and directors** improves **recommendation systems and search efficiency**.
#
# ### **3️⃣ Financial Insights for Investment & Marketing**
# - The dashboard helps identify **high-grossing movies**, enabling better **investment decisions in sequels, reboots, and special screenings**.
# - By analyzing **box office trends and IMDb scores**, businesses can allocate **marketing budgets effectively**, prioritizing movies with a **higher probability of commercial success**.
#
# ### **4️⃣ Streamlining Database Management & Scalability**
# - Performing **CRUD operations (Create, Read, Update, Delete)** ensures that the database remains **clean, optimized, and structured** for long-term usability.
# - Using **MongoDB’s scalability** features, the dataset can be **expanded dynamically** to accommodate new releases **without performance bottlenecks**.
# - The dashboard allows **real-time data updates**, ensuring that **movie-related insights are always current and actionable**.
#
# ### **5️⃣ Insights from the MongoDB Dashboard**
# I have created a **MongoDB-powered Movie Sales Dashboard**, which allows:
# ✅ **Interactive data exploration** of movie records using filters and aggregations.
# ✅ **Real-time updates and modifications** based on CRUD operations.
# ✅ **Visual representation** of movie trends, helping managers make informed decisions.
# 📌 **You can check out the MongoDB Dashboard in this repository!**
#
#
#
# ---
#
# ### **💡 Final Takeaway**
# This project **successfully demonstrates** how **MongoDB** can be leveraged for **movie data analysis, database optimization, and strategic decision-making**. The **MongoDB Dashboard** further enhances usability by providing an **interactive platform** for managing and analyzing movie-related data efficiently.
#
# 📌 **Check out the MongoDB Dashboard in this repository to explore the dataset visually!** 🚀
